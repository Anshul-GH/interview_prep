# %%
import os

# Unset proxy env vars before creating the client
for var in ["HTTP_PROXY", "HTTPS_PROXY", "http_proxy", "https_proxy", "ALL_PROXY", "all_proxy"]:
    os.environ.pop(var, None)

# Explicitly bypass proxy for localhost
os.environ["NO_PROXY"] = "localhost,127.0.0.1"
os.environ["no_proxy"] = "localhost,127.0.0.1"

# %%
import os
import anthropic
from dotenv import load_dotenv

env_path = ".env"
load_dotenv(dotenv_path=env_path, override=True)

client = anthropic.Anthropic(
    # base_url="http://127.0.0.1:11434",
    # api_key="fake-key",
    base_url=os.getenv("ANTHROPIC_BASE_URL"),
    api_key=os.getenv("ANTHROPIC_API_KEY"),
)

llm_model = "llama3.2"

# message = client.messages.create(
#     model=llm_model,
#     max_tokens=1024,
#     messages=[{"role": "user", "content": "Hello! What is Python?"}]
# )
# print(message.content[0].text)

# %%
# message = client.messages.create(
#     model=llm_model,
#     max_tokens=1024,
#     messages=[
#         {
#             "role": "user",
#             "content": "What is quantum computing? Answer in one sentence" 
#         }
#     ]
# )

# print(message.content[0].text)

# message = client.messages.create(
#     model=llm_model,
#     max_tokens=1024,
#     messages=[
#         {
#             "role": "user",
#             "content": "Write another sentence" 
#         }
#     ]
# )

# print(message.content[0].text)

# %% [markdown]
# # Correct Approach

# %%
def add_user_message(messages, text):
    user_message = {
        "role": "user",
        "content": text
    }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    messages.append(assistant_message)

def chat(messages):
    # client = anthropic.Anthropic(
    #     # base_url="http://127.0.0.1:11434",
    #     # api_key="fake-key",
    #     base_url=os.getenv("ANTHROPIC_BASE_URL"),
    #     api_key=os.getenv("ANTHROPIC_API_KEY"),
    # )
    # llm_model = "llama3.2"
    message = client.messages.create(
        model=llm_model,
        max_tokens=1024,
        messages=messages,
    )
    return message.content[0].text

# %%
# make a starting list of messages
messages = []

# add the initial user question
message = "Define quamtum computing in one sentence"
add_user_message(messages, message)

# pass the list of messages into chat to get the answer
answer = chat(messages)

# append the answer into the list
add_assistant_message(messages, answer)

# add a follow up question from the user
message = "Write another sentence"
add_user_message(messages, message)

# pass the list of messages into chat to get the answer
answer = chat(messages)

print(messages)
print(answer)
# Out:
# [{'role': 'user', 'content': 'Define quamtum computing in one sentence'}, {'role': 'assistant', 'content': 'Quantum computing is a type of computing that uses the principles of quantum mechanics to perform calculations and operations on data, leveraging the unique properties of qubits (quantum bits) to potentially solve complex problems exponentially faster than classical computers.'}, {'role': 'user', 'content': 'Write another sentence'}]
# By harnessing the power of superposition, entanglement, and interference, quantum computers can process vast amounts of information in parallel, enabling breakthroughs in fields such as cryptography, optimization, and simulation that are currently unsolvable or require an unfeasible amount of time for classical computers.

# %% [markdown]
# # Create a working chatbot

# %%
import os
import anthropic
from dotenv import load_dotenv

env_path = ".env"
load_dotenv(dotenv_path=env_path, override=True)

client = anthropic.Anthropic(
    # base_url="http://127.0.0.1:11434",
    # api_key="fake-key",
    base_url=os.getenv("ANTHROPIC_BASE_URL"),
    api_key=os.getenv("ANTHROPIC_API_KEY"),
)

llm_model = "llama3.2"

def add_user_message(messages, text):
    user_message = {
        "role": "user",
        "content": text
    }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    messages.append(assistant_message)

def chat(messages):
    # client = anthropic.Anthropic(
    #     # base_url="http://127.0.0.1:11434",
    #     # api_key="fake-key",
    #     base_url=os.getenv("ANTHROPIC_BASE_URL"),
    #     api_key=os.getenv("ANTHROPIC_API_KEY"),
    # )
    # llm_model = "llama3.2"
    message = client.messages.create(
        model=llm_model,
        max_tokens=1024,
        messages=messages,
    )
    return message.content[0].text

def start_chat_bot():
    # list of messages as history
    messages = []

    # run the chatbot forever

    while True:
        user_input = input("> ")
        print("> ", user_input)

        add_user_message(messages, user_input)

        answer = chat(messages)

        add_assistant_message(messages, answer)

        print(">> ", answer)

# %%
start_chat_bot()
# Out:
# >  1 + 1 = ?
# >>  1 + 1 = 2
# >  add another 5 to it
# >>  2 + 5 = 7
# >  who are you
# >>  I am an artificial intelligence language model, designed to assist and communicate with users like you. I'm a computer program that can understand and generate human-like text, answer questions, and provide information on a wide range of topics.
#
# I don't have a personal identity or emotions, but I'm here to help and provide assistance whenever you need it. I'm constantly learning and improving my responses based on the conversations I have with users like you.
#
# So, what can I help you with today?
# >  how can you solve math problems
# >>  I can solve math problems using various algorithms and techniques. Here are some ways I approach math problems:
#
# 1. **Symbolic Manipulation**: I can manipulate mathematical expressions using algebraic and calculus rules to simplify or evaluate them.
# 2. **Numerical Computation**: For numerical problems, I use computational methods to perform calculations with high precision.
# 3. **Pattern Recognition**: I recognize patterns in mathematical expressions, such as arithmetic, geometric, or trigonometric sequences, to solve equations.
# 4. **Algorithms and Formulas**: I have been trained on a vast collection of math formulas, algorithms, and techniques, which I can draw upon to solve specific problems.
#
# Some examples of how I approach math problems:
#
# * **Basic Arithmetic**: I perform addition, subtraction, multiplication, and division operations with ease.
# * **Algebraic Manipulation**: I simplify expressions, factor polynomials, solve linear equations, and find roots using various methods (e.g., substitution, elimination).
# * **Geometry and Trigonometry**: I calculate areas, volumes, lengths, angles, and trigonometric functions like sine, cosine, and tangent.
# * **Calculus**: I differentiate and integrate functions, find maxima and minima, and solve optimization problems.
#
# To solve math problems, I use a combination of natural language processing (NLP) and machine learning techniques to analyze the input expression, identify relevant formulas and concepts, and generate an accurate solution.
#
# Would you like me to help with a specific math problem?
# >  how do I solve 5x + 2 = 3
# >>  To solve for x in the equation 5x + 2 = 3, we need to isolate x on one side of the equation. Here's how:
#
# **Step 1: Subtract 2 from both sides**
#
# We want to get rid of the constant term (+2) that's being added to the product of 5x. To do this, we subtract 2 from both sides of the equation:
#
# 5x + 2 - 2 = 3 - 2
# 5x = 1
#
# **Step 2: Divide both sides by 5**
#
# Now, we want to get rid of the coefficient (5) that's being multiplied by x. To do this, we divide both sides of the equation by 5:
#
# (5x) / 5 = 1 / 5
# x = 1/5
#
# **Answer:**
#
# x = 0.2
#
# So, the value of x in the original equation is 0.2.
#
# How's that? Do you have any questions or would you like me to explain further?
# >  please explain how you got to the answer
# >>  Let's break down the steps I took to solve the equation 5x + 2 = 3:
#
# **Step 1: Subtract 2 from both sides**
#
# My goal is to isolate x, which means getting rid of the constant term (+2) that's being added to the product of 5x. To do this, I subtract 2 from both sides of the equation, like this:
#
# 5x + 2 = 3
# 5x + 2 - 2 = ?
#
# Using the distributive property (also known as FOIL), I "pull out" the 2 that's being added to 5x:
#
# 5x + 2 - 2 = 5x + (-2) = 5x - 2
#
# So, subtracting 2 from both sides gives me a new equation:
#
# 5x - 2 = 3
#
# **Step 2: Add 2 to both sides**
#
# Now that I've "cleared" the constant term (+2), my goal is to get rid of the negative coefficient (-1) that's associated with it. To do this, I add 2 to both sides of the equation:
#
# 5x - 2 = 3
# 5x - 2 + 2 = ?
#
# Using the distributive property (again!), I "push" the 2 onto the right side of the equation:
#
# 5x - 2 + 2 = 5x + (-1) = 5x + 1
#
# Now, adding 2 to both sides gives me a new equation with no negative coefficients:
#
# 5x + 1 = 3
#
# **Step 3: Subtract 1 from both sides**
#
# Next, I want to get rid of the constant term (+1) that's associated with x. To do this, I subtract 1 from both sides of the equation:
#
# 5x + 1 = 3
# 5x + 1 - 1 = ?
#
# Using the distributive property (once more!), I "pull out" the 1 that's being added to 5x:
#
# 5x + 1 - 1 = 5x
#
# So, subtracting 1 from both sides gives me a new equation with no constant terms:
#
# 5x = 2
#
# **Step 4: Divide both sides by 5**
#
# Finally, I want to get rid of the coefficient (5) that's associated with x. To do this, I divide both sides of the equation by 5:
#
# (5x) / 5 = 2 / 5
# x = 2/5
#
# And that's how I arrived at the solution: x = 0.2!
#
# How does this help? Do you have any questions about the process?
# >
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 start_chat_bot()
#
# Cell In[23], line 58, in start_chat_bot()
#      54         print("> ", user_input)
#      55
#      56         add_user_message(messages, user_input)
#      57
# ---> 58         answer = chat(messages)
#      59
#      60         add_assistant_message(messages, answer)
#      61
#
# Cell In[23], line 39, in chat(messages)
#      35     #     base_url=os.getenv("ANTHROPIC_BASE_URL"),
#      36     #     api_key=os.getenv("ANTHROPIC_API_KEY"),
#      37     # )
#      38     # llm_model = "llama3.2"
# ---> 39     message = client.messages.create(
#      40         model=llm_model,
#      41         max_tokens=1024,
#      42         messages=messages,
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/anthropic/_utils/_utils.py:268, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     266             msg = f"Missing required argument: {quote(missing[0])}"
#     267     raise TypeError(msg)
# --> 268 return func(*args, **kwargs)
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/anthropic/resources/messages/messages.py:991, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     984 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#     985     warnings.warn(
#     986         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#     987         UserWarning,
#     988         stacklevel=3,
#     989     )
# --> 991 return self._post(
#     992     "/v1/messages",
#     993     body=maybe_transform(
#     994         {
#     995             "max_tokens": max_tokens,
#     996             "messages": messages,
#     997             "model": model,
#     998             "cache_control": cache_control,
#     999             "container": container,
#    1000             "inference_geo": inference_geo,
#    1001             "metadata": metadata,
#    1002             "output_config": output_config,
#    1003             "service_tier": service_tier,
#    1004             "stop_sequences": stop_sequences,
#    1005             "stream": stream,
#    1006             "system": system,
#    1007             "temperature": temperature,
#    1008             "thinking": thinking,
#    1009             "tool_choice": tool_choice,
#    1010             "tools": tools,
#    1011             "top_k": top_k,
#    1012             "top_p": top_p,
#    1013         },
#    1014         message_create_params.MessageCreateParamsStreaming
#    1015         if stream
#    1016         else message_create_params.MessageCreateParamsNonStreaming,
#    1017     ),
#    1018     options=make_request_options(
#    1019         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1020     ),
#    1021     cast_to=Message,
#    1022     stream=stream or False,
#    1023     stream_cls=Stream[RawMessageStreamEvent],
#    1024 )
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/anthropic/_base_client.py:1368, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1359     warnings.warn(
#    1360         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1361         "Please pass raw bytes via the `content` parameter instead.",
#    1362         DeprecationWarning,
#    1363         stacklevel=2,
#    1364     )
#    1365 opts = FinalRequestOptions.construct(
#    1366     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1367 )
# -> 1368 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/anthropic/_base_client.py:1076, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1074 response = None
#    1075 try:
# -> 1076     response = self._client.send(
#    1077         request,
#    1078         stream=stream or self._should_stream_response_body(request=request),
#    1079         **kwargs,
#    1080     )
#    1081 except httpx.TimeoutException as err:
#    1082     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
