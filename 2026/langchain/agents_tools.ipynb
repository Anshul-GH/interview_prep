# %%
# !pip install langchain

# %%
from langchain.agents import create_agent

agent = create_agent("openai:gpt-5", tools=tools)
# Out:
# /Users/ruchir/Documents/Anshul/Code/interview_prep/.venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from langchain.agents import create_agent
# ----> 3 agent = create_agent("openai:gpt-5", tools=tools)
#
# NameError: name 'tools' is not defined

# %%
# !pip install langchain_openai

# %%
from langchain.agents import create_agent
from langchain_openai import ChatOpenAI

model = ChatOpenAI(
    model="gpt-5",
    temperature=0.1,
    max_tokens=1000,
    timeout=30
)
agent = create_agent(model, tools=tools)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[5], line 4
#       1 from langchain.agents import create_agent
#       2 from langchain_openai import ChatOpenAI
# ----> 4 model = ChatOpenAI(
#       5     model="gpt-5",
#       6     temperature=0.1,
#       7     max_tokens=1000,
#       8     timeout=30
#       9     # ... (other params)
#      10 )
#      11 agent = create_agent(model, tools=tools)
#
# File ~/Documents/Anshul/Code/interview_prep/.venv/lib/python3.14/site-packages/langchain_core/load/serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/Documents/Anshul/Code/interview_prep/.venv/lib/python3.14/site-packages/langchain_openai/chat_models/base.py:1071, in BaseChatOpenAI.validate_environment(self)
#    1061         self.http_async_client = httpx.AsyncClient(
#    1062             proxy=self.openai_proxy, verify=global_ssl_context
#    1063         )
#    1064     async_specific = {
#    1065         "http_client": self.http_async_client
#    1066         or _get_default_async_httpx_client(
#    (...)   1069         "api_key": async_api_key_value,
#    1070     }
# -> 1071     self.root_async_client = openai.AsyncOpenAI(
#    1072         **client_params,
#    1073         **async_specific,  # type: ignore[arg-type]
#    1074     )
#    1075     self.async_client = self.root_async_client.chat.completions
#    1076 return self
#
# File ~/Documents/Anshul/Code/interview_prep/.venv/lib/python3.14/site-packages/openai/_client.py:496, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     494     api_key = os.environ.get("OPENAI_API_KEY")
#     495 if api_key is None:
# --> 496     raise OpenAIError(
#     497         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     498     )
#     499 if callable(api_key):
#     500     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
