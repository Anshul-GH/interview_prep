# %%
import os

# Unset proxy env vars before creating the client
for var in ["HTTP_PROXY", "HTTPS_PROXY", "http_proxy", "https_proxy", "ALL_PROXY", "all_proxy"]:
    os.environ.pop(var, None)

# Explicitly bypass proxy for localhost
os.environ["NO_PROXY"] = "localhost,127.0.0.1"
os.environ["no_proxy"] = "localhost,127.0.0.1"

# %%
import os
import anthropic
from dotenv import load_dotenv

env_path = ".env"
load_dotenv(dotenv_path=env_path, override=True)

client = anthropic.Anthropic(
    # base_url="http://127.0.0.1:11434",
    # api_key="fake-key",
    base_url=os.getenv("ANTHROPIC_BASE_URL"),
    api_key=os.getenv("ANTHROPIC_API_KEY"),
)

llm_model = "llama3.2"

# message = client.messages.create(
#     model=llm_model,
#     max_tokens=1024,
#     messages=[{"role": "user", "content": "Hello! What is Python?"}]
# )
# print(message.content[0].text)

# %%
# message = client.messages.create(
#     model=llm_model,
#     max_tokens=1024,
#     messages=[
#         {
#             "role": "user",
#             "content": "What is quantum computing? Answer in one sentence" 
#         }
#     ]
# )

# print(message.content[0].text)

# message = client.messages.create(
#     model=llm_model,
#     max_tokens=1024,
#     messages=[
#         {
#             "role": "user",
#             "content": "Write another sentence" 
#         }
#     ]
# )

# print(message.content[0].text)

# %% [markdown]
# # Correct Approach

# %%
def add_user_message(messages, text):
    user_message = {
        "role": "user",
        "content": text
    }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    messages.append(assistant_message)

def chat(messages):
    # client = anthropic.Anthropic(
    #     # base_url="http://127.0.0.1:11434",
    #     # api_key="fake-key",
    #     base_url=os.getenv("ANTHROPIC_BASE_URL"),
    #     api_key=os.getenv("ANTHROPIC_API_KEY"),
    # )
    # llm_model = "llama3.2"
    message = client.messages.create(
        model=llm_model,
        max_tokens=1024,
        messages=messages,
    )
    return message.content[0].text

# %%
# make a starting list of messages
messages = []

# add the initial user question
message = "Define quamtum computing in one sentence"
add_user_message(messages, message)

# pass the list of messages into chat to get the answer
answer = chat(messages)

# append the answer into the list
add_assistant_message(messages, answer)

# add a follow up question from the user
message = "Write another sentence"
add_user_message(messages, message)

# pass the list of messages into chat to get the answer
answer = chat(messages)

print(messages)
print(answer)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 9
#       5 message = "Define quamtum computing in one sentence"
#       6 add_user_message(messages, message)
#       7
#       8 # pass the list of messages into chat to get the answer
# ----> 9 answer = chat(messages)
#      10
#      11 # append the answer into the list
#      12 add_assistant_message(messages, answer)
#
# Cell In[8], line 23, in chat(messages)
#      19     #     base_url=os.getenv("ANTHROPIC_BASE_URL"),
#      20     #     api_key=os.getenv("ANTHROPIC_API_KEY"),
#      21     # )
#      22     # llm_model = "llama3.2"
# ---> 23     message = client.messages.create(
#      24         model=llm_model,
#      25         max_tokens=1024,
#      26         messages=messages,
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/anthropic/_utils/_utils.py:268, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     266             msg = f"Missing required argument: {quote(missing[0])}"
#     267     raise TypeError(msg)
# --> 268 return func(*args, **kwargs)
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/anthropic/resources/messages/messages.py:991, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     984 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#     985     warnings.warn(
#     986         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#     987         UserWarning,
#     988         stacklevel=3,
#     989     )
# --> 991 return self._post(
#     992     "/v1/messages",
#     993     body=maybe_transform(
#     994         {
#     995             "max_tokens": max_tokens,
#     996             "messages": messages,
#     997             "model": model,
#     998             "cache_control": cache_control,
#     999             "container": container,
#    1000             "inference_geo": inference_geo,
#    1001             "metadata": metadata,
#    1002             "output_config": output_config,
#    1003             "service_tier": service_tier,
#    1004             "stop_sequences": stop_sequences,
#    1005             "stream": stream,
#    1006             "system": system,
#    1007             "temperature": temperature,
#    1008             "thinking": thinking,
#    1009             "tool_choice": tool_choice,
#    1010             "tools": tools,
#    1011             "top_k": top_k,
#    1012             "top_p": top_p,
#    1013         },
#    1014         message_create_params.MessageCreateParamsStreaming
#    1015         if stream
#    1016         else message_create_params.MessageCreateParamsNonStreaming,
#    1017     ),
#    1018     options=make_request_options(
#    1019         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1020     ),
#    1021     cast_to=Message,
#    1022     stream=stream or False,
#    1023     stream_cls=Stream[RawMessageStreamEvent],
#    1024 )
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/anthropic/_base_client.py:1368, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1359     warnings.warn(
#    1360         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1361         "Please pass raw bytes via the `content` parameter instead.",
#    1362         DeprecationWarning,
#    1363         stacklevel=2,
#    1364     )
#    1365 opts = FinalRequestOptions.construct(
#    1366     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1367 )
# -> 1368 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/anthropic/_base_client.py:1076, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1074 response = None
#    1075 try:
# -> 1076     response = self._client.send(
#    1077         request,
#    1078         stream=stream or self._should_stream_response_body(request=request),
#    1079         **kwargs,
#    1080     )
#    1081 except httpx.TimeoutException as err:
#    1082     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %% [markdown]
# # Create a working chatbot

# %%
import os
import anthropic
from dotenv import load_dotenv

env_path = ".env"
load_dotenv(dotenv_path=env_path, override=True)

client = anthropic.Anthropic(
    # base_url="http://127.0.0.1:11434",
    # api_key="fake-key",
    base_url=os.getenv("ANTHROPIC_BASE_URL"),
    api_key=os.getenv("ANTHROPIC_API_KEY"),
)

llm_model = "llama3.2"

def add_user_message(messages, text):
    user_message = {
        "role": "user",
        "content": text
    }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0):
    params = {
        "model": llm_model,
        "max_tokens": 1024,
        "messages": messages,
        "temperature": temperature
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

def start_chat_bot(system_prompt, temperature):
    # list of messages as history
    messages = []

    # run the chatbot forever

    while True:
        user_input = input("> ")
        print("> ", user_input)

        add_user_message(messages, user_input)

        answer = chat(messages, system_prompt, temperature)
        # answer = chat(messages)

        add_assistant_message(messages, answer)

        print(">> ", answer)

# %%
# system_prompt = """
# You are a patient matth tutor.
# Do not directly answer a student's quetions.
# Guide them to a solution step by step.
# """

# system_prompt = "You are a Python engineer who writes very concise."

# system_prompt = "Generate a one sentence movie idea."
system_prompt = None
temperature = 1.0

start_chat_bot(system_prompt, temperature)
# Out:
# >  who are you
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_sync/http_proxy.py:206, in ForwardHTTPConnection.handle_request(self, request)
#     199 proxy_request = Request(
#     200     method=request.method,
#     201     url=url,
#    (...)    204     extensions=request.extensions,
#     205 )
# --> 206 return self._connection.handle_request(proxy_request)
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_backends/sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File ~/.local/share/mise/installs/python/3.14.2/lib/python3.14/contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 65] No route to host
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/anthropic/_base_client.py:1076, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1075 try:
# -> 1076     response = self._client.send(
#    1077         request,
#    1078         stream=stream or self._should_stream_response_body(request=request),
#    1079         **kwargs,
#    1080     )
#    1081 except httpx.TimeoutException as err:
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpx/_transports/default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File ~/.local/share/mise/installs/python/3.14.2/lib/python3.14/contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 65] No route to host
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[2], line 13
#       9 # system_prompt = "Generate a one sentence movie idea."
#      10 system_prompt = None
#      11 temperature = 1.0
#      12
# ---> 13 start_chat_bot(system_prompt, temperature)
#
# Cell In[1], line 57, in start_chat_bot(system_prompt, temperature)
#      53         print("> ", user_input)
#      54
#      55         add_user_message(messages, user_input)
#      56
# ---> 57         answer = chat(messages, system_prompt, temperature)
#      58         # answer = chat(messages)
#      59
#      60         add_assistant_message(messages, answer)
#
# Cell In[1], line 42, in chat(messages, system, temperature)
#      38
#      39     if system:
#      40         params["system"] = system
#      41
# ---> 42     message = client.messages.create(**params)
#      43     return message.content[0].text
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/anthropic/_utils/_utils.py:268, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     266             msg = f"Missing required argument: {quote(missing[0])}"
#     267     raise TypeError(msg)
# --> 268 return func(*args, **kwargs)
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/anthropic/resources/messages/messages.py:991, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     984 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#     985     warnings.warn(
#     986         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#     987         UserWarning,
#     988         stacklevel=3,
#     989     )
# --> 991 return self._post(
#     992     "/v1/messages",
#     993     body=maybe_transform(
#     994         {
#     995             "max_tokens": max_tokens,
#     996             "messages": messages,
#     997             "model": model,
#     998             "cache_control": cache_control,
#     999             "container": container,
#    1000             "inference_geo": inference_geo,
#    1001             "metadata": metadata,
#    1002             "output_config": output_config,
#    1003             "service_tier": service_tier,
#    1004             "stop_sequences": stop_sequences,
#    1005             "stream": stream,
#    1006             "system": system,
#    1007             "temperature": temperature,
#    1008             "thinking": thinking,
#    1009             "tool_choice": tool_choice,
#    1010             "tools": tools,
#    1011             "top_k": top_k,
#    1012             "top_p": top_p,
#    1013         },
#    1014         message_create_params.MessageCreateParamsStreaming
#    1015         if stream
#    1016         else message_create_params.MessageCreateParamsNonStreaming,
#    1017     ),
#    1018     options=make_request_options(
#    1019         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1020     ),
#    1021     cast_to=Message,
#    1022     stream=stream or False,
#    1023     stream_cls=Stream[RawMessageStreamEvent],
#    1024 )
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/anthropic/_base_client.py:1368, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1359     warnings.warn(
#    1360         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1361         "Please pass raw bytes via the `content` parameter instead.",
#    1362         DeprecationWarning,
#    1363         stacklevel=2,
#    1364     )
#    1365 opts = FinalRequestOptions.construct(
#    1366     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1367 )
# -> 1368 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/Anshul/Code/interview_prep/2026/claude_certified_architect/.claude/lib/python3.14/site-packages/anthropic/_base_client.py:1108, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1105         continue
#    1107     log.debug("Raising connection error")
# -> 1108     raise APIConnectionError(request=request) from err
#    1110 log.debug(
#    1111     'HTTP Response: %s %s "%i %s" %s',
#    1112     request.method,
#    (...)   1116     response.headers,
#    1117 )
#    1118 log.debug("request_id: %s", response.headers.get("request-id"))
#
# APIConnectionError: Connection error.

# %%
import os
import anthropic
from dotenv import load_dotenv

env_path = ".env"
load_dotenv(dotenv_path=env_path, override=True)

client = anthropic.Anthropic(
    # base_url="http://127.0.0.1:11434",
    # api_key="fake-key",
    base_url=os.getenv("ANTHROPIC_BASE_URL"),
    api_key=os.getenv("ANTHROPIC_API_KEY"),
)

llm_model = "llama3.2"

messages = []

add_user_message(messages, "Writte a 1 sentence description of a fake dattabase")

stream = client.messages.create(
    model=llm_model,
    max_tokens=1000,
    messages=messages,
    stream=True
)

for event in stream:
    print(event)
# Out:
# RawMessageStartEvent(message=Message(id='msg_33737d7ba1136cc6a828c374', container=None, content=[], model='llama3.2', role='assistant', stop_details=None, stop_reason=None, stop_sequence=None, type='message', usage=Usage(cache_creation=None, cache_creation_input_tokens=None, cache_read_input_tokens=None, inference_geo=None, input_tokens=13, output_tokens=0, server_tool_use=None, service_tier=None)), type='message_start')
# RawContentBlockStartEvent(content_block=TextBlock(citations=None, text='', type='text'), index=0, type='content_block_start')
# RawContentBlockDeltaEvent(delta=TextDelta(text='The', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' "', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text='Gal', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text='actic', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' Expedition', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' Database', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text='"', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' is', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' a', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' vast', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=',', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' inter', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text='gal', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text='actic', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' repository', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' containing', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' records', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' of', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' over', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' ', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text='100', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=',', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text='000', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' celestial', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' missions', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=',', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' planetary', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' surveys', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=',', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' and', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' extr', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text='ater', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text='restrial', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' encounters', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' spanning', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' thousands', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' of', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' years', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' across', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' the', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' cosmos', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text='.', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockStopEvent(index=0, type='content_block_stop')
# RawMessageDeltaEvent(delta=Delta(container=None, stop_details=None, stop_reason='end_turn', stop_sequence=None), type='message_delta', usage=MessageDeltaUsage(cache_creation_input_tokens=None, cache_read_input_tokens=None, input_tokens=38, output_tokens=43, server_tool_use=None))
# RawMessageStopEvent(type='message_stop')

# %%
import os
import anthropic
from dotenv import load_dotenv

env_path = ".env"
load_dotenv(dotenv_path=env_path, override=True)

client = anthropic.Anthropic(
    # base_url="http://127.0.0.1:11434",
    # api_key="fake-key",
    base_url=os.getenv("ANTHROPIC_BASE_URL"),
    api_key=os.getenv("ANTHROPIC_API_KEY"),
)

llm_model = "llama3.2"

messages = []

add_user_message(messages, "Writte a 1 sentence description of a fake dattabase")

with client.messages.stream(
    model=llm_model,
    max_tokens=1024,
    messages=messages
) as stream:
    for text in stream.text_stream:
        print(text, end="")

stream.get_final_message()
# Out:
# The "Galactic Explorer's Database" is a comprehensive, starship-tracking repository containing over 100,000 entries on various alien species, planetary systems, and intergalactic trade routes.
# ParsedMessage(id='msg_3d6bc9293f29d9ab4ec78d64', container=None, content=[ParsedTextBlock(citations=None, text='The "Galactic Explorer\'s Database" is a comprehensive, starship-tracking repository containing over 100,000 entries on various alien species, planetary systems, and intergalactic trade routes.', type='text', parsed_output=None)], model='llama3.2', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=None, cache_creation_input_tokens=None, cache_read_input_tokens=None, inference_geo=None, input_tokens=38, output_tokens=39, server_tool_use=None, service_tier=None))

# %% [markdown]
# # Structured Datta

# %%
import os
import anthropic
from dotenv import load_dotenv

# Unset proxy env vars before creating the client
for var in ["HTTP_PROXY", "HTTPS_PROXY", "http_proxy", "https_proxy", "ALL_PROXY", "all_proxy"]:
    os.environ.pop(var, None)

# Explicitly bypass proxy for localhost
os.environ["NO_PROXY"] = "localhost,127.0.0.1"
os.environ["no_proxy"] = "localhost,127.0.0.1"

env_path = ".env"
load_dotenv(dotenv_path=env_path, override=True)

client = anthropic.Anthropic(
    # base_url="http://127.0.0.1:11434",
    # api_key="fake-key",
    base_url=os.getenv("ANTHROPIC_BASE_URL"),
    api_key=os.getenv("ANTHROPIC_API_KEY"),
)

llm_model = "llama3.2"

def add_user_message(messages, text):
    user_message = {
        "role": "user",
        "content": text
    }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0, stop_sequences=None):
    params = {
        "model": llm_model,
        "max_tokens": 1024,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

def start_chat_bot(system_prompt, temperature):
    # list of messages as history
    messages = []

    # run the chatbot forever

    while True:
        user_input = input("> ")
        print("> ", user_input)

        add_user_message(messages, user_input)

        answer = chat(messages, system_prompt, temperature)
        # answer = chat(messages)

        add_assistant_message(messages, answer)

        print(">> ", answer)

# %%
messages = []

add_user_message(messages, "Generate a very short event bridge rule as json")
add_assistant_message(messages, "```json")

# text = chat(messages, stop_sequences=["```"])

text = chat(messages)

add_assistant_message(messages, text)

print(text)


# with client.messages.stream(
#     model=llm_model,
#     max_tokens=1024,
#     messages=messages
# ) as stream:
#     for text in stream.text_stream:
#         print(text, end="")

# stream.get_final_message()
# Out:
# {
#   "EventBridge": {
#     "Enabled": true,
#     "Rule": [
#       {
#         "Name": "Example Rule",
#         "Pattern": {
#           "source": ["aws.eventbridge"],
#           "detail-type": ["EC2 Instance State Change"]
#         },
#         "Condition": {
#           "StringEquals": {
#             " detail.statusCode": "200"
#           }
#         },
#         "Targets": [
#           {
#             "Id": "example-target",
#             "Arn": "arn:aws:events:region:account-id:rule/ExampleTargetRule"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```
#
# This is a basic EventBridge rule that triggers when an EC2 instance's state changes to 'running', and only if the status code of the request is 200. It sends an alert to a specified event bridge target (not included in this example, but it should point to your own target).

# %%
messages = []

add_user_message(messages, "Generate a very short event bridge rule as json")
add_assistant_message(messages, "```json")

text = chat(messages, stop_sequences=["```"])

# text = chat(messages)

add_assistant_message(messages, text)

print(text)
# Out:
# {
#   "eventBridge": {
#     "eventPattern": [
#       {
#         "source": ["aws.ec2"],
#         "detail-type": ["EC2 Instance State Change"]
#       }
#     ],
#     "statistics": [],
#     "destinationArn": "arn:aws:events:REGION:ACCOUNT_ID:rule/EC2-Instance-State-Change"
#   }
# }

# %% [markdown]
# # Exercise to test formatting

# %%
messages = []

prompt = """
Generate three different AWS CLI commands. Each command should be very very small.
"""

add_user_message(messages, prompt)
add_assistant_message(messages, "Here are all the three commands in single block without any comments:\n`")

# text = chat(messages)
text = chat(messages, stop_sequences=["`"])

print(text)


# add_assistant_message(messages, text)

# print(text.strip())
# Out:
# aws ec2 create-security-group --group-name test
# aws s3api put-bucket-policy --bucket mytest --policy '{"Version": "2012-10-17", "Statement": [{"Sid": "", "Effect": "Allow", "Principal": "*", "Action": ["s3:PutObject"], "Resource": ["arn:aws:s3:::mytest/*"}]}'
# aws elb create-load-balancer -l 1

# %% [markdown]
# # Prompt Evaluation Framework

# %%
import os
import re
import ast
import anthropic
from dotenv import load_dotenv

# Unset proxy env vars before creating the client
for var in ["HTTP_PROXY", "HTTPS_PROXY", "http_proxy", "https_proxy", "ALL_PROXY", "all_proxy"]:
    os.environ.pop(var, None)

# Explicitly bypass proxy for localhost
os.environ["NO_PROXY"] = "localhost,127.0.0.1"
os.environ["no_proxy"] = "localhost,127.0.0.1"

env_path = ".env"
load_dotenv(dotenv_path=env_path, override=True)

client = anthropic.Anthropic(
    # base_url="http://127.0.0.1:11434",
    # api_key="fake-key",
    base_url=os.getenv("ANTHROPIC_BASE_URL"),
    api_key=os.getenv("ANTHROPIC_API_KEY"),
)

llm_model = "llama3.2"

def add_user_message(messages, text):
    user_message = {
        "role": "user",
        "content": text
    }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0, stop_sequences=None):
    params = {
        "model": llm_model,
        "max_tokens": 1024,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

def start_chat_bot(system_prompt, temperature):
    # list of messages as history
    messages = []

    # run the chatbot forever

    while True:
        user_input = input("> ")
        print("> ", user_input)

        add_user_message(messages, user_input)

        answer = chat(messages, system_prompt, temperature)
        # answer = chat(messages)

        add_assistant_message(messages, answer)

        print(">> ", answer)

import json

def generate_dataset(count=3):
    prompt = """
    Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
    that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
    each representing task that requires Python, JSON, or a Regex to complete.

    Example output:
    json
    [
        {
            "task": "Description of task",
            "format": "json" or "python" or "regex",
            "solution_criteria": "Key criteria for evaluating the solution"
        },
        ...additional
    ]


    * Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
    * Focus on tasks that do not require writing much code

    Please generate {count} objects.
    """

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])

    return json.loads(text)

# %%
dataset = generate_dataset(10)

with open("prompt_dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# validators
def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0

def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0

def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0
    
def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
"""

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result."""
    prompt = f"""
    Please solve the following task:

    {test_case["task"]}

    * Respond only with Python, JSON or a plain Regex
    * Do not add any comments or commentary or explanation
    """
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    
    return output

def run_test_case(test_case):
    """Calls run_prompt, then grades the result."""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score)/2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning
    }

def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case."""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = (sum([result["score"] for result in results])/len(results))
    print(f"Average Score: {average_score}")

    return results

# %%
with open("prompt_dataset.json", "r") as f:
    dataset = json.load(f)

# print(dataset)
results = run_eval(dataset)

# write the results in a file
with open("prompt_eval_result.json", "w") as f:
    json.dump(results, f, indent=2)

# Previous Score: 7.2
# Next Score: 7.9375
# Next Iteration: 7.142857142857143
# Out:
# /var/folders/q8/3493b1yj245144r0q6kz5nn80000gn/T/ipykernel_29537/3059114269.py:18: FutureWarning: Possible nested set at position 481
#   re.compile(text.strip())
# Average Score: 7.142857142857143
